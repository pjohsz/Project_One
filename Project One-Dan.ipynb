# %%
# Dependencies
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime
import numpy as np
from pandas import DataFrame
from pandas import Series
import tweepy

# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# Twitter API Keys
from config import (consumer_key,
                    consumer_secret,
                    access_token,
                    access_token_secret)

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Save path to movies data file in a variable
data_file = "Resources/movie_data.csv"

# Use Pandas to read data
movie_df = pd.read_csv(data_file)
movie_df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy
# 2                 11000.0  200074175.0        Action|Adventure|Thriller
# 3                 27000.0  448130642.0                  Action|Thriller
# 4                   131.0  936662225.0                      Documentary
#
#           ...          num_user_for_reviews language  country  content_rating  \
# 0         ...                        3054.0  English      USA           PG-13
# 1         ...                        1238.0  English      USA           PG-13
# 2         ...                         994.0  English       UK           PG-13
# 3         ...                        2701.0  English      USA           PG-13
# 4         ...                           NaN      NaN      NaN             NaN
#
#         budget  title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0  237000000.0      2009.0                  936.0        7.9          1.78
# 1  300000000.0      2007.0                 5000.0        7.1          2.35
# 2  245000000.0      2015.0                  393.0        6.8          2.35
# 3  250000000.0      2012.0                23000.0        8.5          2.35
# 4  306000000.0      2015.0                   12.0        7.1           NaN
#
#   movie_facebook_likes
# 0                33000
# 1                    0
# 2                85000
# 3               164000
# 4                    0
#
# [5 rows x 28 columns]

# %%
# Clean the data frame to remove the "Â" value in the movie title
# %timeit movie_df.movie_title.apply(lambda x: x.replace('Â',''))

movie_df.head()
# Out:
# 2.15 ms ± 229 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy
# 2                 11000.0  200074175.0        Action|Adventure|Thriller
# 3                 27000.0  448130642.0                  Action|Thriller
# 4                   131.0  936662225.0                      Documentary
#
#           ...          num_user_for_reviews language  country  content_rating  \
# 0         ...                        3054.0  English      USA           PG-13
# 1         ...                        1238.0  English      USA           PG-13
# 2         ...                         994.0  English       UK           PG-13
# 3         ...                        2701.0  English      USA           PG-13
# 4         ...                           NaN      NaN      NaN             NaN
#
#         budget  title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0  237000000.0      2009.0                  936.0        7.9          1.78
# 1  300000000.0      2007.0                 5000.0        7.1          2.35
# 2  245000000.0      2015.0                  393.0        6.8          2.35
# 3  250000000.0      2012.0                23000.0        8.5          2.35
# 4  306000000.0      2015.0                   12.0        7.1           NaN
#
#   movie_facebook_likes
# 0                33000
# 1                    0
# 2                85000
# 3               164000
# 4                    0
#
# [5 rows x 28 columns]

# %%
# remove rows where any of the columns are set to NaN
movie_df = movie_df.dropna(how='any')

movie_df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 5  Color     Andrew Stanton                   462.0     132.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 5                    475.0                   530.0   Samantha Morton
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy
# 2                 11000.0  200074175.0        Action|Adventure|Thriller
# 3                 27000.0  448130642.0                  Action|Thriller
# 5                   640.0   73058679.0          Action|Adventure|Sci-Fi
#
#           ...          num_user_for_reviews language  country  content_rating  \
# 0         ...                        3054.0  English      USA           PG-13
# 1         ...                        1238.0  English      USA           PG-13
# 2         ...                         994.0  English       UK           PG-13
# 3         ...                        2701.0  English      USA           PG-13
# 5         ...                         738.0  English      USA           PG-13
#
#         budget  title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0  237000000.0      2009.0                  936.0        7.9          1.78
# 1  300000000.0      2007.0                 5000.0        7.1          2.35
# 2  245000000.0      2015.0                  393.0        6.8          2.35
# 3  250000000.0      2012.0                23000.0        8.5          2.35
# 5  263700000.0      2012.0                  632.0        6.6          2.35
#
#   movie_facebook_likes
# 0                33000
# 1                    0
# 2                85000
# 3               164000
# 5                24000
#
# [5 rows x 28 columns]

# %%
list(movie_df)
# Out:
# ['color',
#  'director_name',
#  'num_critic_for_reviews',
#  'duration',
#  'director_facebook_likes',
#  'actor_3_facebook_likes',
#  'actor_2_name',
#  'actor_1_facebook_likes',
#  'gross',
#  'genres',
#  'actor_1_name',
#  'movie_title',
#  'num_voted_users',
#  'cast_total_facebook_likes',
#  'actor_3_name',
#  'facenumber_in_poster',
#  'plot_keywords',
#  'movie_imdb_link',
#  'num_user_for_reviews',
#  'language',
#  'country',
#  'content_rating',
#  'budget',
#  'title_year',
#  'actor_2_facebook_likes',
#  'imdb_score',
#  'aspect_ratio',
#  'movie_facebook_likes']

# %%
# Create dataframe that is only starwars.
Dan_chart_df = movie_df.loc[:, ["movie_title", "movie_facebook_likes"]]
Dan_chart_df = movie_df[Dan_chart_df['movie_title'].str.contains("Star Wars")] 
Dan_chart_df
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 236   Color      George Lucas                   359.0     140.0
# 237   Color      George Lucas                   284.0     142.0
# 240   Color      George Lucas                   320.0     136.0
# 1536  Color  Richard Marquand                   197.0     134.0
# 2051  Color    Irvin Kershner                   223.0     127.0
# 3024  Color      George Lucas                   282.0     125.0
#
#       director_facebook_likes  actor_3_facebook_likes     actor_2_name  \
# 236                       0.0                  4000.0  Christopher Lee
# 237                       0.0                  4000.0  Christopher Lee
# 240                       0.0                  1000.0      Liam Neeson
# 1536                     37.0                   504.0    Ian McDiarmid
# 2051                    883.0                   441.0      Kenny Baker
# 3024                      0.0                   504.0    Peter Cushing
#
#       actor_1_facebook_likes        gross                           genres  \
# 236                  20000.0  380262555.0  Action|Adventure|Fantasy|Sci-Fi
# 237                  20000.0  310675583.0  Action|Adventure|Fantasy|Sci-Fi
# 240                  20000.0  474544677.0  Action|Adventure|Fantasy|Sci-Fi
# 1536                 11000.0  309125409.0  Action|Adventure|Fantasy|Sci-Fi
# 2051                 11000.0  290158751.0  Action|Adventure|Fantasy|Sci-Fi
# 3024                 11000.0  460935665.0  Action|Adventure|Fantasy|Sci-Fi
#
#              ...          num_user_for_reviews language  country  \
# 236          ...                        3286.0  English      USA
# 237          ...                        3516.0  English      USA
# 240          ...                        3597.0  English      USA
# 1536         ...                         647.0  English      USA
# 2051         ...                         900.0  English      USA
# 3024         ...                        1470.0  English      USA
#
#       content_rating       budget  title_year actor_2_facebook_likes  \
# 236            PG-13  113000000.0      2005.0                16000.0
# 237               PG  115000000.0      2002.0                16000.0
# 240               PG  115000000.0      1999.0                14000.0
# 1536              PG   32500000.0      1983.0                 1000.0
# 2051              PG   18000000.0      1980.0                  504.0
# 3024              PG   11000000.0      1977.0                 1000.0
#
#      imdb_score  aspect_ratio movie_facebook_likes
# 236         7.6          2.35                10000
# 237         6.7          1.78                    0
# 240         6.5          2.35                13000
# 1536        8.4          2.35                14000
# 2051        8.8          2.35                17000
# 3024        8.7          2.35                33000
#
# [6 rows x 28 columns]

# %%
Dan_chart_df = movie_df.loc[:, ["movie_title", "movie_facebook_likes"]]
Dan_chart_df = movie_df[Dan_chart_df['movie_title'].str.contains("Star Trek")] 
Dan_chart_df
# Out:
#       color    director_name  num_critic_for_reviews  duration  \
# 48    Color      J.J. Abrams                   590.0     132.0
# 57    Color       Justin Lin                   322.0     122.0
# 160   Color      J.J. Abrams                   518.0     127.0
# 600   Color  Jonathan Frakes                   160.0     103.0
# 778   Color     Stuart Baird                   172.0     116.0
# 1067  Color  Jonathan Frakes                   143.0     111.0
# 1343  Color     David Carson                    98.0     118.0
# 1409  Color      Robert Wise                   134.0     143.0
# 1631  Color  William Shatner                    98.0     107.0
# 1803  Color   Nicholas Meyer                   112.0     110.0
# 2018  Color    Leonard Nimoy                   106.0     119.0
# 2396  Color    Leonard Nimoy                   110.0     105.0
# 2923  Color   Nicholas Meyer                   148.0     116.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 48                    14000.0                   928.0   Bruce Greenwood
# 57                      681.0                   105.0  Melissa Roxburgh
# 160                   14000.0                   981.0     Leonard Nimoy
# 600                     906.0                   748.0   Jonathan Frakes
# 778                      53.0                   906.0      LeVar Burton
# 1067                    906.0                   906.0     Alfre Woodard
# 1343                     18.0                   906.0         Alan Ruck
# 1409                    338.0                   643.0  Nichelle Nichols
# 1631                      0.0                   643.0  Nichelle Nichols
# 1803                    120.0                   664.0    Kurtwood Smith
# 2018                  12000.0                   643.0  Nichelle Nichols
# 2396                  12000.0                   643.0  Nichelle Nichols
# 2923                    120.0                   664.0     Kirstie Alley
#
#       actor_1_facebook_likes        gross  \
# 48                   19000.0  228756232.0
# 57                     998.0  130468626.0
# 160                  26000.0  257704099.0
# 600                   1000.0   70117571.0
# 778                  27000.0   43119879.0
# 1067                  1000.0   92001027.0
# 1343                  1000.0   75668868.0
# 1409                 12000.0   82300000.0
# 1631                 12000.0   55210049.0
# 1803                 12000.0   74888996.0
# 2018                 12000.0  109713132.0
# 2396                 12000.0   76400000.0
# 2923                 12000.0   78900000.0
#
#                                         genres         ...           \
# 48                     Action|Adventure|Sci-Fi         ...
# 57            Action|Adventure|Sci-Fi|Thriller         ...
# 160                    Action|Adventure|Sci-Fi         ...
# 600           Action|Adventure|Sci-Fi|Thriller         ...
# 778           Action|Adventure|Sci-Fi|Thriller         ...
# 1067    Action|Adventure|Drama|Sci-Fi|Thriller         ...
# 1343  Action|Adventure|Mystery|Sci-Fi|Thriller         ...
# 1409                  Adventure|Mystery|Sci-Fi         ...
# 1631          Action|Adventure|Sci-Fi|Thriller         ...
# 1803          Action|Adventure|Sci-Fi|Thriller         ...
# 2018                   Adventure|Comedy|Sci-Fi         ...
# 2396                   Action|Adventure|Sci-Fi         ...
# 2923                   Action|Adventure|Sci-Fi         ...
#
#      num_user_for_reviews language  country  content_rating       budget  \
# 48                 1171.0  English      USA           PG-13  190000000.0
# 57                  432.0  English      USA           PG-13  185000000.0
# 160                1559.0  English      USA           PG-13  150000000.0
# 600                 515.0  English      USA              PG   58000000.0
# 778                 842.0  English      USA           PG-13   60000000.0
# 1067                286.0  English      USA           PG-13   45000000.0
# 1343                249.0  English      USA              PG   35000000.0
# 1409                405.0  English      USA              PG   35000000.0
# 1631                293.0  English      USA              PG   27800000.0
# 1803                188.0  English      USA              PG   30000000.0
# 2018                219.0  English      USA              PG   25000000.0
# 2396                192.0  English      USA              PG   17000000.0
# 2923                359.0  English      USA              PG   11000000.0
#
#       title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 48        2013.0                  981.0        7.8          2.35
# 57        2016.0                  119.0        7.5          2.35
# 160       2009.0                12000.0        8.0          2.35
# 600       1998.0                  906.0        6.4          2.35
# 778       2002.0                 1000.0        6.4          2.35
# 1067      1996.0                 1000.0        7.6          2.35
# 1343      1994.0                  946.0        6.6          2.35
# 1409      1979.0                  664.0        6.4          2.35
# 1631      1989.0                  664.0        5.4          2.35
# 1803      1991.0                 1000.0        7.2          2.35
# 2018      1986.0                  664.0        7.3          2.35
# 2396      1984.0                  664.0        6.6          2.35
# 2923      1982.0                  980.0        7.7          2.35
#
#      movie_facebook_likes
# 48                  92000
# 57                  30000
# 160                 19000
# 600                  1000
# 778                     0
# 1067                 3000
# 1343                    0
# 1409                    0
# 1631                    0
# 1803                    0
# 2018                    0
# 2396                    0
# 2923                    0
#
# [13 rows x 28 columns]

# %%
Dan_chart_df = movie_df.loc[:, ["movie_title", "movie_facebook_likes"]]
Dan_chart_df = movie_df[Dan_chart_df['movie_title'].str.contains("Star Wars")] 
Dan_chart_df['movie_facebook_likes'] = Dan_chart_df['movie_facebook_likes']
just_fblikes = Dan_chart_df[[ "movie_title", "title_year", "movie_facebook_likes"]]
just_fblikes2 = just_fblikes.sort_values(by="movie_facebook_likes", ascending=False)
just_fblikes2.head(10)
# Out:
# /Users/danielevans/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                           movie_title  title_year  \
# 3024              Star Wars: Episode IV - A New Hope       1977.0
# 2051  Star Wars: Episode V - The Empire Strikes Back       1980.0
# 1536      Star Wars: Episode VI - Return of the Jedi       1983.0
# 240        Star Wars: Episode I - The Phantom Menace       1999.0
# 236     Star Wars: Episode III - Revenge of the Sith       2005.0
# 237     Star Wars: Episode II - Attack of the Clones       2002.0
#
#       movie_facebook_likes
# 3024                 33000
# 2051                 17000
# 1536                 14000
# 240                  13000
# 236                  10000
# 237                      0

# %%
# Create bar chart for Starwars Franchise
movie_titles = just_fblikes2['movie_title']
movie_likes = just_fblikes2['movie_facebook_likes']

y_axis = np.arange(len(movie_titles))
x_axis = np.arange(len(movie_likes))

plt.barh(y_axis, movie_likes, color="rgbcm", align="center")

# Tell matplotlib where we would like to place each of our x axis headers
tick_locations = [value for value in x_axis]
plt.yticks(tick_locations, just_fblikes2['movie_title'])

# Get the current date for display
now = datetime.now()
now = now.strftime("%m/%d/%Y")

# Give our chart some labels and a tile
plt.title(f"Star Wars social Analysis ({now})")
plt.ylabel("Movie Title")
plt.xlabel("Facebook likes per movie")

# Save Figure
plt.savefig("Fig1.png")

# Show plot
plt.show()

# %%
Dan_chart_df1 = movie_df.loc[:, ["movie_title", "movie_facebook_likes"]]
Dan_chart_df1 = movie_df[Dan_chart_df1['movie_title'].str.contains("Star Trek")] 
Dan_chart_df1['movie_facebook_likes'] = Dan_chart_df1['movie_facebook_likes']
just_fblikes1 = Dan_chart_df1[[ "movie_title", "title_year", "movie_facebook_likes"]]
just_fblikes3 = just_fblikes1.sort_values(by="movie_facebook_likes", ascending=False)
just_fblikes3.head(10)
# Out:
# /Users/danielevans/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                   movie_title  title_year  \
# 48                   Star Trek Into Darkness       2013.0
# 57                          Star Trek Beyond       2016.0
# 160                                Star Trek       2009.0
# 1067                Star Trek: First Contact       1996.0
# 600                  Star Trek: Insurrection       1998.0
# 778                       Star Trek: Nemesis       2002.0
# 1343                  Star Trek: Generations       1994.0
# 1409           Star Trek: The Motion Picture       1979.0
# 1631         Star Trek V: The Final Frontier       1989.0
# 1803  Star Trek VI: The Undiscovered Country       1991.0
#
#       movie_facebook_likes
# 48                   92000
# 57                   30000
# 160                  19000
# 1067                  3000
# 600                   1000
# 778                      0
# 1343                     0
# 1409                     0
# 1631                     0
# 1803                     0

# %%
# Create bar chart for Starwars Franchise
movie_titles = just_fblikes3['movie_title']
movie_likes = just_fblikes3['movie_facebook_likes']

y_axis = np.arange(len(movie_titles))
x_axis = np.arange(len(movie_likes))

plt.barh(y_axis, movie_likes, color="rgbmc", align="center")

# Tell matplotlib where we would like to place each of our x axis headers
tick_locations = [value for value in x_axis]
plt.yticks(tick_locations, just_fblikes3['movie_title'])

# Get the current date for display
now = datetime.now()
now = now.strftime("%m/%d/%Y")

# Give our chart some labels and a tile
plt.title(f"Star Trek social Analysis ({now})")
plt.ylabel("Movie Title")
plt.xlabel("Facebook likes per movie")

# Save Figure
plt.savefig("Fig1.png")

# Show plot
plt.show()

# %%
Dan_chart_df2 = movie_df.loc[:, ["movie_title", "movie_facebook_likes"]]
Dan_chart_df2 = movie_df[Dan_chart_df2['movie_title'].str.contains("Star Wars")] 
Dan_chart_df2['actor_1_facebook_likes'] = Dan_chart_df2['actor_1_facebook_likes']
just_fblikes = Dan_chart_df2[[ "movie_title", "title_year", "actor_1_name", "actor_1_facebook_likes"]]
just_fblikes2 = just_fblikes.sort_values(by="actor_1_facebook_likes", ascending=False)
just_fblikes2.head(10)
# Out:
# /Users/danielevans/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                           movie_title  title_year  \
# 236     Star Wars: Episode III - Revenge of the Sith       2005.0
# 237     Star Wars: Episode II - Attack of the Clones       2002.0
# 240        Star Wars: Episode I - The Phantom Menace       1999.0
# 1536      Star Wars: Episode VI - Return of the Jedi       1983.0
# 2051  Star Wars: Episode V - The Empire Strikes Back       1980.0
# 3024              Star Wars: Episode IV - A New Hope       1977.0
#
#          actor_1_name  actor_1_facebook_likes
# 236   Natalie Portman                 20000.0
# 237   Natalie Portman                 20000.0
# 240   Natalie Portman                 20000.0
# 1536    Harrison Ford                 11000.0
# 2051    Harrison Ford                 11000.0
# 3024    Harrison Ford                 11000.0

# %%
# Create bar chart for Starwars Franchise
movie_titles = just_fblikes2['actor_1_name']
movie_likes = just_fblikes2['actor_1_facebook_likes']

y_axis = np.arange(len(movie_titles))
x_axis = np.arange(len(movie_likes))

plt.barh(y_axis, movie_likes, color="r", align="center")

# Tell matplotlib where we would like to place each of our x axis headers
tick_locations = [value for value in x_axis]
plt.yticks(tick_locations, just_fblikes2['actor_1_name'])

# Get the current date for display
now = datetime.now()
now = now.strftime("%m/%d/%Y")

# Give our chart some labels and a tile
plt.title(f"Star Wars social Analysis ({now})")
plt.ylabel("Actor/Actress Title")
plt.xlabel("Facebook likes of actor per movie")

# Save Figure
plt.savefig("Fig1.png")

# Show plot
plt.show()

# %%
Dan_chart_df3 = movie_df.loc[:, ["movie_title", "movie_facebook_likes"]]
Dan_chart_df3 = movie_df[Dan_chart_df3['movie_title'].str.contains("Star Trek")] 
Dan_chart_df3['actor_1_facebook_likes'] = Dan_chart_df3['actor_1_facebook_likes']
just_fblikes = Dan_chart_df3[[ "movie_title", "title_year", "actor_1_name", "actor_1_facebook_likes"]]
just_fblikes2 = just_fblikes.sort_values(by="actor_1_facebook_likes", ascending=False)
just_fblikes2.head(10)
# Out:
# /Users/danielevans/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                   movie_title  title_year  \
# 778                       Star Trek: Nemesis       2002.0
# 160                                Star Trek       2009.0
# 48                   Star Trek Into Darkness       2013.0
# 1409           Star Trek: The Motion Picture       1979.0
# 1631         Star Trek V: The Final Frontier       1989.0
# 1803  Star Trek VI: The Undiscovered Country       1991.0
# 2018           Star Trek IV: The Voyage Home       1986.0
# 2396     Star Trek III: The Search for Spock       1984.0
# 2923         Star Trek II: The Wrath of Khan       1982.0
# 600                  Star Trek: Insurrection       1998.0
#
#               actor_1_name  actor_1_facebook_likes
# 778              Tom Hardy                 27000.0
# 160        Chris Hemsworth                 26000.0
# 48    Benedict Cumberbatch                 19000.0
# 1409         Leonard Nimoy                 12000.0
# 1631         Leonard Nimoy                 12000.0
# 1803         Leonard Nimoy                 12000.0
# 2018         Leonard Nimoy                 12000.0
# 2396         Leonard Nimoy                 12000.0
# 2923         Leonard Nimoy                 12000.0
# 600           LeVar Burton                  1000.0

# %%
# Create bar chart for Starwars Franchise
movie_titles = just_fblikes2['actor_1_name']
movie_likes = just_fblikes2['actor_1_facebook_likes']

y_axis = np.arange(len(movie_titles))
x_axis = np.arange(len(movie_likes))

plt.barh(y_axis, movie_likes, color="g", align="center")

# Tell matplotlib where we would like to place each of our x axis headers
tick_locations = [value for value in x_axis]
plt.yticks(tick_locations, just_fblikes2['actor_1_name'])

# Get the current date for display
now = datetime.now()
now = now.strftime("%m/%d/%Y")

# Give our chart some labels and a tile
plt.title(f"Star Trek social Analysis ({now})")
plt.ylabel("Actor Actress Name")
plt.xlabel("Facebook likes of actor per movie")

# Save Figure
plt.savefig("Fig1.png")

# Show plot
plt.show()

# %%
# Extract movie name, release date, budget and gross values
reduced_movie_df = movie_df.loc[:, ["movie_title", "budget", "gross","title_year"]]
reduced_movie_df

reduced_movie_df.head()
# Out:
#                                  movie_title       budget        gross  \
# 0                                    Avatar   237000000.0  760505847.0
# 1  Pirates of the Caribbean: At World's End   300000000.0  309404152.0
# 2                                   Spectre   245000000.0  200074175.0
# 3                     The Dark Knight Rises   250000000.0  448130642.0
# 5                               John Carter   263700000.0   73058679.0
#
#    title_year
# 0      2009.0
# 1      2007.0
# 2      2015.0
# 3      2012.0
# 5      2012.0

# %%
Dan_chart_df = movie_df.loc[:, ["movie_title", "movie_facebook_likes"]]
Dan_chart_df
Dan_chart_df.head()
# Out:
#                                  movie_title  movie_facebook_likes
# 0                                    Avatar                  33000
# 1  Pirates of the Caribbean: At World's End                      0
# 2                                   Spectre                  85000
# 3                     The Dark Knight Rises                 164000
# 5                               John Carter                  24000

# %%
# Extract the Star Wars Movie information
starwars_df = reduced_movie_df[reduced_movie_df['movie_title'].str.contains("Star Wars")] 
starwars_df

starwars_df['budget'] = starwars_df['budget'].astype(float).map("${:,.2f}".format)
starwars_df['gross'] = starwars_df['gross'].astype(float).map("${:,.2f}".format)
starwars_df['title_year'] = starwars_df['title_year'].astype(int)

starwars_df.head(10)
# Out:
# /Users/danielevans/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /Users/danielevans/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/danielevans/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#                                           movie_title           budget  \
# 236     Star Wars: Episode III - Revenge of the Sith   $113,000,000.00
# 237     Star Wars: Episode II - Attack of the Clones   $115,000,000.00
# 240        Star Wars: Episode I - The Phantom Menace   $115,000,000.00
# 1536      Star Wars: Episode VI - Return of the Jedi    $32,500,000.00
# 2051  Star Wars: Episode V - The Empire Strikes Back    $18,000,000.00
# 3024              Star Wars: Episode IV - A New Hope    $11,000,000.00
#
#                 gross  title_year
# 236   $380,262,555.00        2005
# 237   $310,675,583.00        2002
# 240   $474,544,677.00        1999
# 1536  $309,125,409.00        1983
# 2051  $290,158,751.00        1980
# 3024  $460,935,665.00        1977

# %%
# Create bar chart for Starwars Franchise
movie_titles = starwars_df['movie_title']
movie_gross = starwars_df['gross']
movie_budget = starwars_df['budget']

y_axis = np.arange(len(movie_titles))
x_axis = np.arange(len(movie_gross))

plt.barh(y_axis, movie_gross, color="g", align="center")
plt.barh(y_axis, movie_budget, color="b", align="center")

# Tell matplotlib where we would like to place each of our x axis headers
tick_locations = [value for value in x_axis]
plt.yticks(tick_locations, starwars_df['movie_title'])

# Get the current date for display
now = datetime.now()
now = now.strftime("%m/%d/%Y")

# Give our chart some labels and a tile
plt.title(f"Star Wars Finacial Analysis ({now})")
plt.ylabel("Movie Title")
plt.xlabel("Movie Financials")

# Save Figure
plt.savefig("Fig1.png")

# Show plot
plt.show()
