# %%
# Dependencies
import tweepy
import json
from api import consumer_key, consumer_secret, access_token, access_token_secret
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
df = pd.DataFrame(columns= ['searchterm','id','txt','pos','neg','neu','cmpnd'])
analyzer = SentimentIntensityAnalyzer()


#HashtagList
hl = ['#thelastjedi','#AStarWarsStory','#starwars','#TheForceAwakens','#RogueOne','#StarTrek','#StarTrekbeyond','#StarTrekIntoDarkness','#StarTrekDiscovery']

#AtList
al = ['@StarWars','@startrekcbs','@StarTrekMovie','@StarTrek']

# %%
for el in hl:    
    public_tweets = api.search(el + ' -filter:retweets', count = 10000 ,lang = 'en')
    for tweet in public_tweets["statuses"]:
        vs = analyzer.polarity_scores(tweet["text"])
        strel = str(el)
        tid = str(tweet['id'])
        txt = str(tweet['text']).replace("\n","").replace(",","|")
        pos = vs['pos']
        neg = vs['neg']
        neu = vs['neu']
        cmp = vs['compound']
        df2 = pd.DataFrame.from_records([(strel,tid,txt,pos,neg,neu,cmp)])
        df2.columns = ['searchterm','id','txt','pos','neg','neu','cmpnd']
        df = df.append(df2, ignore_index = True, sort = False)
#print(df)
for el in al:    
    public_tweets = api.search(el + ' -filter:retweets', count = 10000 ,lang = 'en')
    for tweet in public_tweets["statuses"]:
        vs = analyzer.polarity_scores(tweet["text"])
        strel = str(el)
        tid = str(tweet['id'])
        txt = str(tweet['text']).replace("\n","").replace(",","|")
        pos = vs['pos']
        neg = vs['neg']
        neu = vs['neu']
        cmp = vs['compound']
        df2 = pd.DataFrame.from_records([(strel,tid,txt,pos,neg,neu,cmp)])
        df2.columns = ['searchterm','id','txt','pos','neg','neu','cmpnd']
        df = df.append(df2, ignore_index = True, sort = False)
#print(df)

# %%
df = df.dropna()

# %%
df.to_csv('starWars_starTrek_apiRes.csv')

# %%
df_sw = df.loc[df['searchterm'] == '#starwars']
df_sw_cmp_mean = df_sw['cmpnd'].mean()
df_sw_pos_mean = df_sw['pos'].mean()
df_sw_neg_mean = df_sw['neg'].mean()
df_sw_cmp_searchterm = df_sw['searchterm'].unique()

df_st = df.loc[df['searchterm'] == '#StarTrek']
df_st_cmp_mean = df_st['cmpnd'].mean()
df_st_pos_mean = df_st['pos'].mean()
df_st_neg_mean = df_st['neg'].mean()
df_st_cmp_searchterm = df_st['searchterm'].unique()

df_tlj = df.loc[df['searchterm'] == '#thelastjedi']
df_tlj_cmp_mean = df_tlj['cmpnd'].mean()
df_tlj_pos_mean = df_tlj['pos'].mean()
df_tlj_neg_mean = df_tlj['neg'].mean()
df_tlj_cmp_searchterm = df_tlj['searchterm'].unique()

df_ss = df.loc[df['searchterm'] == '#AStarWarsStory']
df_ss_cmp_mean = df_ss['cmpnd'].mean()
df_ss_pos_mean = df_ss['pos'].mean()
df_ss_neg_mean = df_ss['neg'].mean()
df_ss_cmp_searchterm = df_ss['searchterm'].unique()

df_tfa = df.loc[df['searchterm'] == '#TheForceAwakens']
df_tfa_cmp_mean = df_tfa['cmpnd'].mean()
df_tfa_pos_mean = df_tfa['pos'].mean()
df_tfa_neg_mean = df_tfa['neg'].mean()
df_tfa_cmp_searchterm = df_tfa['searchterm'].unique()

df_ro = df.loc[df['searchterm'] == '#RogueOne']
df_ro_cmp_mean = df_ro['cmpnd'].mean()
df_ro_pos_mean = df_ro['pos'].mean()
df_ro_neg_mean = df_ro['neg'].mean()
df_ro_cmp_searchterm = df_ro['searchterm'].unique()

df_stb = df.loc[df['searchterm'] == '#StarTrekbeyond']
df_stb_cmp_mean = df_stb['cmpnd'].mean()
df_stb_pos_mean = df_stb['pos'].mean()
df_stb_neg_mean = df_stb['neg'].mean()
df_stb_cmp_searchterm = df_stb['searchterm'].unique()

df_stid = df.loc[df['searchterm'] == '#StarTrekIntoDarkness']
df_stid_cmp_mean = df_stid['cmpnd'].mean()
df_stid_pos_mean = df_stid['pos'].mean()
df_stid_neg_mean = df_stid['neg'].mean()
df_stid_cmp_searchterm = df_stid['searchterm'].unique()

df_std = df.loc[df['searchterm'] == '#StarTrekDiscovery']
df_std_cmp_mean = df_std['cmpnd'].mean()
df_std_pos_mean = df_std['pos'].mean()
df_std_neg_mean = df_std['neg'].mean()
df_std_cmp_searchterm = df_std['searchterm'].unique()



df_asw = df.loc[df['searchterm'] == '@StarWars']
df_asw_cmp_mean = df_asw['cmpnd'].mean()
df_asw_pos_mean = df_asw['pos'].mean()
df_asw_neg_mean = df_asw['neg'].mean()
df_asw_cmp_searchterm = df_asw['searchterm'].unique()

df_astc = df.loc[df['searchterm'] == '@startrekcbs']
df_astc_cmp_mean = df_astc['cmpnd'].mean()
df_astc_pos_mean = df_astc['pos'].mean()
df_astc_neg_mean = df_astc['neg'].mean()
df_astc_cmp_searchterm = df_astc['searchterm'].unique()

df_astm = df.loc[df['searchterm'] == '@StarTrekMovie']
df_astm_cmp_mean = df_astm['cmpnd'].mean()
df_astm_pos_mean = df_astm['pos'].mean()
df_astm_neg_mean = df_astm['neg'].mean()
df_astm_cmp_searchterm = df_astm['searchterm'].unique()

df_ast = df.loc[df['searchterm'] == '@StarTrek']
df_ast_cmp_mean = df_ast['cmpnd'].mean()
df_ast_pos_mean = df_ast['pos'].mean()
df_ast_neg_mean = df_ast['neg'].mean()
df_ast_cmp_searchterm = df_ast['searchterm'].unique()



cmpd_means= [df_sw_cmp_mean,df_st_cmp_mean,df_tlj_cmp_mean,df_ss_cmp_mean,df_tfa_cmp_mean
             ,df_ro_cmp_mean,df_stb_cmp_mean,df_stid_cmp_mean,df_std_cmp_mean
            ,df_asw_cmp_mean,df_astc_cmp_mean,df_astm_cmp_mean,df_ast_cmp_mean]

pos_means= [df_sw_pos_mean,df_st_pos_mean,df_tlj_pos_mean,df_ss_pos_mean,df_tfa_pos_mean
             ,df_ro_pos_mean,df_stb_pos_mean,df_stid_pos_mean,df_std_pos_mean
            ,df_asw_pos_mean,df_astc_pos_mean,df_astm_pos_mean,df_ast_pos_mean]

neg_means= [df_sw_neg_mean,df_st_neg_mean,df_tlj_neg_mean,df_ss_neg_mean,df_tfa_neg_mean
             ,df_ro_neg_mean,df_stb_neg_mean,df_stid_neg_mean,df_std_neg_mean
            ,df_asw_neg_mean,df_astc_neg_mean,df_astm_neg_mean,df_ast_neg_mean]

searchterms = [df_sw_cmp_searchterm[0],df_st_cmp_searchterm[0],df_tlj_cmp_searchterm[0],df_ss_cmp_searchterm[0],df_tfa_cmp_searchterm[0]
               ,df_ro_cmp_searchterm[0],df_stb_cmp_searchterm[0],df_stid_cmp_searchterm[0],df_std_cmp_searchterm[0]
              ,df_asw_cmp_searchterm[0],df_astc_cmp_searchterm[0],df_astm_cmp_searchterm[0],df_ast_cmp_searchterm[0]]

plt.bar(np.arange(len(cmpd_means)), cmpd_means, color='b', alpha=0.5, align="center")
tick_locations = [value for value in cmpd_means]
plt.xticks(np.arange(len(cmpd_means)),searchterms, rotation = 75)
plt.xlabel('Search Terms')
plt.ylabel('Scores')
plt.title('Average of Compound Scores by Search Term')
plt.tight_layout()
plt.show()
plt.savefig("avg_cmp_srch.png")

# %%
plt.bar(np.arange(len(pos_means)), pos_means, color='g', alpha=0.5, align="center")
tick_locations = [value for value in pos_means]
plt.xticks(np.arange(len(pos_means)),searchterms, rotation = 75)
plt.xlabel('Search Terms')
plt.ylabel('Scores')
plt.title('Average of Positive Scores by Search Term')
plt.tight_layout()
plt.show()
plt.savefig("avg_pos_srch.png")

# %%
plt.bar(np.arange(len(neg_means)), neg_means, color='r', alpha=0.5, align="center")
tick_locations = [value for value in neg_means]
plt.xticks(np.arange(len(neg_means)),searchterms, rotation = 75)
plt.xlabel('Search Terms')
plt.ylabel('Scores')
plt.title('Average of Negative Scores by Search Term')
plt.tight_layout()
plt.show()
plt.savefig("avg_neg_srch.png")

# %%
'''
#What can we learn from these 3 graphs?
1. #AStarWarsStory was much more well liked than the other recent star wars movies
2. StarTrek seems to do better over time.  As a whole comments with their hashtags are less negative.
3. There might be some recency bias as Star Trek Beyond and Solo because they were the most recent movies
   released for each franchise but clearly had the best scores on the sentiment analysis.  Further research is necessary.
4. Let's take a deeper dive on the compound score on the 2 best movies.   
'''
# Out:
# "\n#What can we learn from these 3 graphs?\n1. #AStarWarsStory was much more well liked than the other recent star wars movies\n2. StarTrek seems to do better over time.  As a whole comments with their hashtags are less negative.\n3. There might be some recency bias as Star Trek Beyond and Solo because they were the most recent movies\n   released for each franchise but clearly had the best scores on the sentiment analysis.  Further research is necessary.\n4. Let's take a deeper dive on the compound score on the 2 best movies.   \n"

# %%
data = [df_stb['cmpnd'].values,df_ss['cmpnd'].values]
#xtickNames = plt.setp(ax1, np.array([df_ss_cmp_searchterm[0],df_stb_cmp_searchterm[0]]))
fig, ax1 = plt.subplots(figsize=(10, 6))
bp = plt.boxplot(data)
plt.setp(bp['boxes'], color = 'blue')
plt.setp(bp['whiskers'], color='green')
ax1.yaxis.grid(True, linestyle='-', which='major', color='lightgrey',
               alpha=0.75)
ax1.set_title('Comparison of Compound Scores Distribution #AStarWarsStory vs #StarTrekBeyond')
ax1.set_xlabel('Hastags')
ax1.set_ylabel('Values')
plt.xticks([1,2],[df_ss_cmp_searchterm[0],df_stb_cmp_searchterm[0]])
plt.savefig("boxWhisk_StarWar_StarTrek.png")

# %%
'''
#What can we learn from this graph?
1. #StarTrekBeyond comments hit higher highs and lower lows.  The range of values greatly exceeds that of #AStarWarsStory
2. #AStarWarsStory had mainly positive values and no negative values (in terms of compound scores)
'''
# Out:
# '\n#What can we learn from this graph?\n1. #StarTrekBeyond comments hit higher highs and lower lows.  The range of values greatly exceeds that of #AStarWarsStory\n2. #AStarWarsStory had mainly positive values and no negative values (in terms of compound scores)\n'
